# %% [markdown]
# 5번. 2년전 연간 생산량이 10만개, 1년후 15만개, 이후 25만개까지 늘림. 연평균 생산량은 몇배 증가하였는가?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -> 기하평균 공식에 대입!

# %%
import pandas as pd
import numpy as np

round(((250000/100000)**(1/2))-1,2)
# Out:
# 0.58
