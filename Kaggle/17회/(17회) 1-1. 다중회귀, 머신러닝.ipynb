# %% [markdown]
# 데이터 설명 : 집과 관련된 여러 수치들과 집의 가격, log1p 정규화된 price 컬럼 예측 하기

# %% [markdown]
# ### 1. EDA 및 전처리

# %%
import pandas as pd
import numpy as np
data=pd.read_csv('problem1.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            1460 non-null   int64
#  1   LotArea       1460 non-null   int64
#  2   LotFrontage   1201 non-null   float64
#  3   YearBuilt     1460 non-null   int64
#  4   1stFlrSF      1460 non-null   int64
#  5   2ndFlrSF      1460 non-null   int64
#  6   YearRemodAdd  1460 non-null   int64
#  7   TotRmsAbvGrd  1460 non-null   int64
#  8   KitchenAbvGr  1460 non-null   int64
#  9   BedroomAbvGr  1460 non-null   int64
#  10  GarageCars    1460 non-null   int64
#  11  GarageArea    1460 non-null   int64
#  12  price         1460 non-null   float64
# dtypes: float64(2), int64(11)
# memory usage: 148.4 KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
data.plot(kind='box', subplots=True, layout=(2,7), figsize=(20,10), fontsize=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2. Train,Valid,Test set으로 분할 및 시각화 제시

# %%
data2=data.copy()

data2=data2.rename(columns={'1stFlrSF':'first', '2ndFlrSF':'second'})

# %% [markdown]
# - 년도 데이터의 경우 최대년도 기준 몇년전인지 값으로 대체

# %%
#절댓값(지어진년도-지어진년도.max)
data2['YearBuilt']  = abs(data2['YearBuilt']-data2['YearBuilt'].max())
#절댓값(리모델링년도-리모델링년도.max)
data2['YearRemodAdd']  = abs(data2['YearRemodAdd']-data2['YearRemodAdd'].max())

# %%
X=data2.drop(columns=['Id', 'price', 'LotFrontage'])
y=data2['price']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y)

# %%
sc=StandardScaler()
sc.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train_sc=sc.transform(X_train)
X_test_sc=sc.transform(X_test)

# %%
pd.DataFrame(X_train_sc, columns=X_train.columns).plot(kind='box', subplots=True, layout=(2,5), figsize=(20,10), fontsize=15)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp/ipykernel_17692/886060483.py in <module>
#       1 pd.DataFrame(X_train_sc, columns=X_train.columns).plot(kind='box', subplots=True, layout=(2,5), figsize=(20,10), fontsize=15)
# ----> 2 plt.tight_layout()
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ↑ 회귀분석 시 스케일링 하지 않는 것이 r-squred 값이 더 높게 나옴

# %% [markdown]
# ### 3. 2차 교호작용항 까지 고려한 회귀분석 수행 및 변수 선택 과정 제시

# %%
from itertools import permutations
#2차 교호작용항 컬럼 생성
comb=list(permutations(X_train.columns, 3))
len(comb)
comb
# Out:
# [('LotArea', 'YearBuilt', 'first'),
#  ('LotArea', 'YearBuilt', 'second'),
#  ('LotArea', 'YearBuilt', 'YearRemodAdd'),
#  ('LotArea', 'YearBuilt', 'TotRmsAbvGrd'),
#  ('LotArea', 'YearBuilt', 'KitchenAbvGr'),
#  ('LotArea', 'YearBuilt', 'BedroomAbvGr'),
#  ('LotArea', 'YearBuilt', 'GarageCars'),
#  ('LotArea', 'YearBuilt', 'GarageArea'),
#  ('LotArea', 'first', 'YearBuilt'),
#  ('LotArea', 'first', 'second'),
#  ('LotArea', 'first', 'YearRemodAdd'),
#  ('LotArea', 'first', 'TotRmsAbvGrd'),
#  ('LotArea', 'first', 'KitchenAbvGr'),
#  ('LotArea', 'first', 'BedroomAbvGr'),
#  ('LotArea', 'first', 'GarageCars'),
#  ('LotArea', 'first', 'GarageArea'),
#  ('LotArea', 'second', 'YearBuilt'),
#  ('LotArea', 'second', 'first'),
#  ('LotArea', 'second', 'YearRemodAdd'),
#  ('LotArea', 'second', 'TotRmsAbvGrd'),
#  ('LotArea', 'second', 'KitchenAbvGr'),
#  ('LotArea', 'second', 'BedroomAbvGr'),
#  ('LotArea', 'second', 'GarageCars'),
#  ('LotArea', 'second', 'GarageArea'),
#  ('LotArea', 'YearRemodAdd', 'YearBuilt'),
#  ('LotArea', 'YearRemodAdd', 'first'),
#  ('LotArea', 'YearRemodAdd', 'second'),
#  ('LotArea', 'YearRemodAdd', 'TotRmsAbvGrd'),
#  ('LotArea', 'YearRemodAdd', 'KitchenAbvGr'),
#  ('LotArea', 'YearRemodAdd', 'BedroomAbvGr'),
#  ('LotArea', 'YearRemodAdd', 'GarageCars'),
#  ('LotArea', 'YearRemodAdd', 'GarageArea'),
#  ('LotArea', 'TotRmsAbvGrd', 'YearBuilt'),
#  ('LotArea', 'TotRmsAbvGrd', 'first'),
#  ('LotArea', 'TotRmsAbvGrd', 'second'),
#  ('LotArea', 'TotRmsAbvGrd', 'YearRemodAdd'),
#  ('LotArea', 'TotRmsAbvGrd', 'KitchenAbvGr'),
#  ('LotArea', 'TotRmsAbvGrd', 'BedroomAbvGr'),
#  ('LotArea', 'TotRmsAbvGrd', 'GarageCars'),
#  ('LotArea', 'TotRmsAbvGrd', 'GarageArea'),
#  ('LotArea', 'KitchenAbvGr', 'YearBuilt'),
#  ('LotArea', 'KitchenAbvGr', 'first'),
#  ('LotArea', 'KitchenAbvGr', 'second'),
#  ('LotArea', 'KitchenAbvGr', 'YearRemodAdd'),
#  ('LotArea', 'KitchenAbvGr', 'TotRmsAbvGrd'),
#  ('LotArea', 'KitchenAbvGr', 'BedroomAbvGr'),
#  ('LotArea', 'KitchenAbvGr', 'GarageCars'),
#  ('LotArea', 'KitchenAbvGr', 'GarageArea'),
#  ('LotArea', 'BedroomAbvGr', 'YearBuilt'),
#  ('LotArea', 'BedroomAbvGr', 'first'),
#  ('LotArea', 'BedroomAbvGr', 'second'),
#  ('LotArea', 'BedroomAbvGr', 'YearRemodAdd'),
#  ('LotArea', 'BedroomAbvGr', 'TotRmsAbvGrd'),
#  ('LotArea', 'BedroomAbvGr', 'KitchenAbvGr'),
#  ('LotArea', 'BedroomAbvGr', 'GarageCars'),
#  ('LotArea', 'BedroomAbvGr', 'GarageArea'),
#  ('LotArea', 'GarageCars', 'YearBuilt'),
#  ('LotArea', 'GarageCars', 'first'),
#  ('LotArea', 'GarageCars', 'second'),
#  ('LotArea', 'GarageCars', 'YearRemodAdd'),
#  ('LotArea', 'GarageCars', 'TotRmsAbvGrd'),
#  ('LotArea', 'GarageCars', 'KitchenAbvGr'),
#  ('LotArea', 'GarageCars', 'BedroomAbvGr'),
#  ('LotArea', 'GarageCars', 'GarageArea'),
#  ('LotArea', 'GarageArea', 'YearBuilt'),
#  ('LotArea', 'GarageArea', 'first'),
#  ('LotArea', 'GarageArea', 'second'),
#  ('LotArea', 'GarageArea', 'YearRemodAdd'),
#  ('LotArea', 'GarageArea', 'TotRmsAbvGrd'),
#  ('LotArea', 'GarageArea', 'KitchenAbvGr'),
#  ('LotArea', 'GarageArea', 'BedroomAbvGr'),
#  ('LotArea', 'GarageArea', 'GarageCars'),
#  ('YearBuilt', 'LotArea', 'first'),
#  ('YearBuilt', 'LotArea', 'second'),
#  ('YearBuilt', 'LotArea', 'YearRemodAdd'),
#  ('YearBuilt', 'LotArea', 'TotRmsAbvGrd'),
#  ('YearBuilt', 'LotArea', 'KitchenAbvGr'),
#  ('YearBuilt', 'LotArea', 'BedroomAbvGr'),
#  ('YearBuilt', 'LotArea', 'GarageCars'),
#  ('YearBuilt', 'LotArea', 'GarageArea'),
#  ('YearBuilt', 'first', 'LotArea'),
#  ('YearBuilt', 'first', 'second'),
#  ('YearBuilt', 'first', 'YearRemodAdd'),
#  ('YearBuilt', 'first', 'TotRmsAbvGrd'),
#  ('YearBuilt', 'first', 'KitchenAbvGr'),
#  ('YearBuilt', 'first', 'BedroomAbvGr'),
#  ('YearBuilt', 'first', 'GarageCars'),
#  ('YearBuilt', 'first', 'GarageArea'),
#  ('YearBuilt', 'second', 'LotArea'),
#  ('YearBuilt', 'second', 'first'),
#  ('YearBuilt', 'second', 'YearRemodAdd'),
#  ('YearBuilt', 'second', 'TotRmsAbvGrd'),
#  ('YearBuilt', 'second', 'KitchenAbvGr'),
#  ('YearBuilt', 'second', 'BedroomAbvGr'),
#  ('YearBuilt', 'second', 'GarageCars'),
#  ('YearBuilt', 'second', 'GarageArea'),
#  ('YearBuilt', 'YearRemodAdd', 'LotArea'),
#  ('YearBuilt', 'YearRemodAdd', 'first'),
#  ('YearBuilt', 'YearRemodAdd', 'second'),
#  ('YearBuilt', 'YearRemodAdd', 'TotRmsAbvGrd'),
#  ('YearBuilt', 'YearRemodAdd', 'KitchenAbvGr'),
#  ('YearBuilt', 'YearRemodAdd', 'BedroomAbvGr'),
#  ('YearBuilt', 'YearRemodAdd', 'GarageCars'),
#  ('YearBuilt', 'YearRemodAdd', 'GarageArea'),
#  ('YearBuilt', 'TotRmsAbvGrd', 'LotArea'),
#  ('YearBuilt', 'TotRmsAbvGrd', 'first'),
#  ('YearBuilt', 'TotRmsAbvGrd', 'second'),
#  ('YearBuilt', 'TotRmsAbvGrd', 'YearRemodAdd'),
#  ('YearBuilt', 'TotRmsAbvGrd', 'KitchenAbvGr'),
#  ('YearBuilt', 'TotRmsAbvGrd', 'BedroomAbvGr'),
#  ('YearBuilt', 'TotRmsAbvGrd', 'GarageCars'),
#  ('YearBuilt', 'TotRmsAbvGrd', 'GarageArea'),
#  ('YearBuilt', 'KitchenAbvGr', 'LotArea'),
#  ('YearBuilt', 'KitchenAbvGr', 'first'),
#  ('YearBuilt', 'KitchenAbvGr', 'second'),
#  ('YearBuilt', 'KitchenAbvGr', 'YearRemodAdd'),
#  ('YearBuilt', 'KitchenAbvGr', 'TotRmsAbvGrd'),
#  ('YearBuilt', 'KitchenAbvGr', 'BedroomAbvGr'),
#  ('YearBuilt', 'KitchenAbvGr', 'GarageCars'),
#  ('YearBuilt', 'KitchenAbvGr', 'GarageArea'),
#  ('YearBuilt', 'BedroomAbvGr', 'LotArea'),
#  ('YearBuilt', 'BedroomAbvGr', 'first'),
#  ('YearBuilt', 'BedroomAbvGr', 'second'),
#  ('YearBuilt', 'BedroomAbvGr', 'YearRemodAdd'),
#  ('YearBuilt', 'BedroomAbvGr', 'TotRmsAbvGrd'),
#  ('YearBuilt', 'BedroomAbvGr', 'KitchenAbvGr'),
#  ('YearBuilt', 'BedroomAbvGr', 'GarageCars'),
#  ('YearBuilt', 'BedroomAbvGr', 'GarageArea'),
#  ('YearBuilt', 'GarageCars', 'LotArea'),
#  ('YearBuilt', 'GarageCars', 'first'),
#  ('YearBuilt', 'GarageCars', 'second'),
#  ('YearBuilt', 'GarageCars', 'YearRemodAdd'),
#  ('YearBuilt', 'GarageCars', 'TotRmsAbvGrd'),
#  ('YearBuilt', 'GarageCars', 'KitchenAbvGr'),
#  ('YearBuilt', 'GarageCars', 'BedroomAbvGr'),
#  ('YearBuilt', 'GarageCars', 'GarageArea'),
#  ('YearBuilt', 'GarageArea', 'LotArea'),
#  ('YearBuilt', 'GarageArea', 'first'),
#  ('YearBuilt', 'GarageArea', 'second'),
#  ('YearBuilt', 'GarageArea', 'YearRemodAdd'),
#  ('YearBuilt', 'GarageArea', 'TotRmsAbvGrd'),
#  ('YearBuilt', 'GarageArea', 'KitchenAbvGr'),
#  ('YearBuilt', 'GarageArea', 'BedroomAbvGr'),
#  ('YearBuilt', 'GarageArea', 'GarageCars'),
#  ('first', 'LotArea', 'YearBuilt'),
#  ('first', 'LotArea', 'second'),
#  ('first', 'LotArea', 'YearRemodAdd'),
#  ('first', 'LotArea', 'TotRmsAbvGrd'),
#  ('first', 'LotArea', 'KitchenAbvGr'),
#  ('first', 'LotArea', 'BedroomAbvGr'),
#  ('first', 'LotArea', 'GarageCars'),
#  ('first', 'LotArea', 'GarageArea'),
#  ('first', 'YearBuilt', 'LotArea'),
#  ('first', 'YearBuilt', 'second'),
#  ('first', 'YearBuilt', 'YearRemodAdd'),
#  ('first', 'YearBuilt', 'TotRmsAbvGrd'),
#  ('first', 'YearBuilt', 'KitchenAbvGr'),
#  ('first', 'YearBuilt', 'BedroomAbvGr'),
#  ('first', 'YearBuilt', 'GarageCars'),
#  ('first', 'YearBuilt', 'GarageArea'),
#  ('first', 'second', 'LotArea'),
#  ('first', 'second', 'YearBuilt'),
#  ('first', 'second', 'YearRemodAdd'),
#  ('first', 'second', 'TotRmsAbvGrd'),
#  ('first', 'second', 'KitchenAbvGr'),
#  ('first', 'second', 'BedroomAbvGr'),
#  ('first', 'second', 'GarageCars'),
#  ('first', 'second', 'GarageArea'),
#  ('first', 'YearRemodAdd', 'LotArea'),
#  ('first', 'YearRemodAdd', 'YearBuilt'),
#  ('first', 'YearRemodAdd', 'second'),
#  ('first', 'YearRemodAdd', 'TotRmsAbvGrd'),
#  ('first', 'YearRemodAdd', 'KitchenAbvGr'),
#  ('first', 'YearRemodAdd', 'BedroomAbvGr'),
#  ('first', 'YearRemodAdd', 'GarageCars'),
#  ('first', 'YearRemodAdd', 'GarageArea'),
#  ('first', 'TotRmsAbvGrd', 'LotArea'),
#  ('first', 'TotRmsAbvGrd', 'YearBuilt'),
#  ('first', 'TotRmsAbvGrd', 'second'),
#  ('first', 'TotRmsAbvGrd', 'YearRemodAdd'),
#  ('first', 'TotRmsAbvGrd', 'KitchenAbvGr'),
#  ('first', 'TotRmsAbvGrd', 'BedroomAbvGr'),
#  ('first', 'TotRmsAbvGrd', 'GarageCars'),
#  ('first', 'TotRmsAbvGrd', 'GarageArea'),
#  ('first', 'KitchenAbvGr', 'LotArea'),
#  ('first', 'KitchenAbvGr', 'YearBuilt'),
#  ('first', 'KitchenAbvGr', 'second'),
#  ('first', 'KitchenAbvGr', 'YearRemodAdd'),
#  ('first', 'KitchenAbvGr', 'TotRmsAbvGrd'),
#  ('first', 'KitchenAbvGr', 'BedroomAbvGr'),
#  ('first', 'KitchenAbvGr', 'GarageCars'),
#  ('first', 'KitchenAbvGr', 'GarageArea'),
#  ('first', 'BedroomAbvGr', 'LotArea'),
#  ('first', 'BedroomAbvGr', 'YearBuilt'),
#  ('first', 'BedroomAbvGr', 'second'),
#  ('first', 'BedroomAbvGr', 'YearRemodAdd'),
#  ('first', 'BedroomAbvGr', 'TotRmsAbvGrd'),
#  ('first', 'BedroomAbvGr', 'KitchenAbvGr'),
#  ('first', 'BedroomAbvGr', 'GarageCars'),
#  ('first', 'BedroomAbvGr', 'GarageArea'),
#  ('first', 'GarageCars', 'LotArea'),
#  ('first', 'GarageCars', 'YearBuilt'),
#  ('first', 'GarageCars', 'second'),
#  ('first', 'GarageCars', 'YearRemodAdd'),
#  ('first', 'GarageCars', 'TotRmsAbvGrd'),
#  ('first', 'GarageCars', 'KitchenAbvGr'),
#  ('first', 'GarageCars', 'BedroomAbvGr'),
#  ('first', 'GarageCars', 'GarageArea'),
#  ('first', 'GarageArea', 'LotArea'),
#  ('first', 'GarageArea', 'YearBuilt'),
#  ('first', 'GarageArea', 'second'),
#  ('first', 'GarageArea', 'YearRemodAdd'),
#  ('first', 'GarageArea', 'TotRmsAbvGrd'),
#  ('first', 'GarageArea', 'KitchenAbvGr'),
#  ('first', 'GarageArea', 'BedroomAbvGr'),
#  ('first', 'GarageArea', 'GarageCars'),
#  ('second', 'LotArea', 'YearBuilt'),
#  ('second', 'LotArea', 'first'),
#  ('second', 'LotArea', 'YearRemodAdd'),
#  ('second', 'LotArea', 'TotRmsAbvGrd'),
#  ('second', 'LotArea', 'KitchenAbvGr'),
#  ('second', 'LotArea', 'BedroomAbvGr'),
#  ('second', 'LotArea', 'GarageCars'),
#  ('second', 'LotArea', 'GarageArea'),
#  ('second', 'YearBuilt', 'LotArea'),
#  ('second', 'YearBuilt', 'first'),
#  ('second', 'YearBuilt', 'YearRemodAdd'),
#  ('second', 'YearBuilt', 'TotRmsAbvGrd'),
#  ('second', 'YearBuilt', 'KitchenAbvGr'),
#  ('second', 'YearBuilt', 'BedroomAbvGr'),
#  ('second', 'YearBuilt', 'GarageCars'),
#  ('second', 'YearBuilt', 'GarageArea'),
#  ('second', 'first', 'LotArea'),
#  ('second', 'first', 'YearBuilt'),
#  ('second', 'first', 'YearRemodAdd'),
#  ('second', 'first', 'TotRmsAbvGrd'),
#  ('second', 'first', 'KitchenAbvGr'),
#  ('second', 'first', 'BedroomAbvGr'),
#  ('second', 'first', 'GarageCars'),
#  ('second', 'first', 'GarageArea'),
#  ('second', 'YearRemodAdd', 'LotArea'),
#  ('second', 'YearRemodAdd', 'YearBuilt'),
#  ('second', 'YearRemodAdd', 'first'),
#  ('second', 'YearRemodAdd', 'TotRmsAbvGrd'),
#  ('second', 'YearRemodAdd', 'KitchenAbvGr'),
#  ('second', 'YearRemodAdd', 'BedroomAbvGr'),
#  ('second', 'YearRemodAdd', 'GarageCars'),
#  ('second', 'YearRemodAdd', 'GarageArea'),
#  ('second', 'TotRmsAbvGrd', 'LotArea'),
#  ('second', 'TotRmsAbvGrd', 'YearBuilt'),
#  ('second', 'TotRmsAbvGrd', 'first'),
#  ('second', 'TotRmsAbvGrd', 'YearRemodAdd'),
#  ('second', 'TotRmsAbvGrd', 'KitchenAbvGr'),
#  ('second', 'TotRmsAbvGrd', 'BedroomAbvGr'),
#  ('second', 'TotRmsAbvGrd', 'GarageCars'),
#  ('second', 'TotRmsAbvGrd', 'GarageArea'),
#  ('second', 'KitchenAbvGr', 'LotArea'),
#  ('second', 'KitchenAbvGr', 'YearBuilt'),
#  ('second', 'KitchenAbvGr', 'first'),
#  ('second', 'KitchenAbvGr', 'YearRemodAdd'),
#  ('second', 'KitchenAbvGr', 'TotRmsAbvGrd'),
#  ('second', 'KitchenAbvGr', 'BedroomAbvGr'),
#  ('second', 'KitchenAbvGr', 'GarageCars'),
#  ('second', 'KitchenAbvGr', 'GarageArea'),
#  ('second', 'BedroomAbvGr', 'LotArea'),
#  ('second', 'BedroomAbvGr', 'YearBuilt'),
#  ('second', 'BedroomAbvGr', 'first'),
#  ('second', 'BedroomAbvGr', 'YearRemodAdd'),
#  ('second', 'BedroomAbvGr', 'TotRmsAbvGrd'),
#  ('second', 'BedroomAbvGr', 'KitchenAbvGr'),
#  ('second', 'BedroomAbvGr', 'GarageCars'),
#  ('second', 'BedroomAbvGr', 'GarageArea'),
#  ('second', 'GarageCars', 'LotArea'),
#  ('second', 'GarageCars', 'YearBuilt'),
#  ('second', 'GarageCars', 'first'),
#  ('second', 'GarageCars', 'YearRemodAdd'),
#  ('second', 'GarageCars', 'TotRmsAbvGrd'),
#  ('second', 'GarageCars', 'KitchenAbvGr'),
#  ('second', 'GarageCars', 'BedroomAbvGr'),
#  ('second', 'GarageCars', 'GarageArea'),
#  ('second', 'GarageArea', 'LotArea'),
#  ('second', 'GarageArea', 'YearBuilt'),
#  ('second', 'GarageArea', 'first'),
#  ('second', 'GarageArea', 'YearRemodAdd'),
#  ('second', 'GarageArea', 'TotRmsAbvGrd'),
#  ('second', 'GarageArea', 'KitchenAbvGr'),
#  ('second', 'GarageArea', 'BedroomAbvGr'),
#  ('second', 'GarageArea', 'GarageCars'),
#  ('YearRemodAdd', 'LotArea', 'YearBuilt'),
#  ('YearRemodAdd', 'LotArea', 'first'),
#  ('YearRemodAdd', 'LotArea', 'second'),
#  ('YearRemodAdd', 'LotArea', 'TotRmsAbvGrd'),
#  ('YearRemodAdd', 'LotArea', 'KitchenAbvGr'),
#  ('YearRemodAdd', 'LotArea', 'BedroomAbvGr'),
#  ('YearRemodAdd', 'LotArea', 'GarageCars'),
#  ('YearRemodAdd', 'LotArea', 'GarageArea'),
#  ('YearRemodAdd', 'YearBuilt', 'LotArea'),
#  ('YearRemodAdd', 'YearBuilt', 'first'),
#  ('YearRemodAdd', 'YearBuilt', 'second'),
#  ('YearRemodAdd', 'YearBuilt', 'TotRmsAbvGrd'),
#  ('YearRemodAdd', 'YearBuilt', 'KitchenAbvGr'),
#  ('YearRemodAdd', 'YearBuilt', 'BedroomAbvGr'),
#  ('YearRemodAdd', 'YearBuilt', 'GarageCars'),
#  ('YearRemodAdd', 'YearBuilt', 'GarageArea'),
#  ('YearRemodAdd', 'first', 'LotArea'),
#  ('YearRemodAdd', 'first', 'YearBuilt'),
#  ('YearRemodAdd', 'first', 'second'),
#  ('YearRemodAdd', 'first', 'TotRmsAbvGrd'),
#  ('YearRemodAdd', 'first', 'KitchenAbvGr'),
#  ('YearRemodAdd', 'first', 'BedroomAbvGr'),
#  ('YearRemodAdd', 'first', 'GarageCars'),
#  ('YearRemodAdd', 'first', 'GarageArea'),
#  ('YearRemodAdd', 'second', 'LotArea'),
#  ('YearRemodAdd', 'second', 'YearBuilt'),
#  ('YearRemodAdd', 'second', 'first'),
#  ('YearRemodAdd', 'second', 'TotRmsAbvGrd'),
#  ('YearRemodAdd', 'second', 'KitchenAbvGr'),
#  ('YearRemodAdd', 'second', 'BedroomAbvGr'),
#  ('YearRemodAdd', 'second', 'GarageCars'),
#  ('YearRemodAdd', 'second', 'GarageArea'),
#  ('YearRemodAdd', 'TotRmsAbvGrd', 'LotArea'),
#  ('YearRemodAdd', 'TotRmsAbvGrd', 'YearBuilt'),
#  ('YearRemodAdd', 'TotRmsAbvGrd', 'first'),
#  ('YearRemodAdd', 'TotRmsAbvGrd', 'second'),
#  ('YearRemodAdd', 'TotRmsAbvGrd', 'KitchenAbvGr'),
#  ('YearRemodAdd', 'TotRmsAbvGrd', 'BedroomAbvGr'),
#  ('YearRemodAdd', 'TotRmsAbvGrd', 'GarageCars'),
#  ('YearRemodAdd', 'TotRmsAbvGrd', 'GarageArea'),
#  ('YearRemodAdd', 'KitchenAbvGr', 'LotArea'),
#  ('YearRemodAdd', 'KitchenAbvGr', 'YearBuilt'),
#  ('YearRemodAdd', 'KitchenAbvGr', 'first'),
#  ('YearRemodAdd', 'KitchenAbvGr', 'second'),
#  ('YearRemodAdd', 'KitchenAbvGr', 'TotRmsAbvGrd'),
#  ('YearRemodAdd', 'KitchenAbvGr', 'BedroomAbvGr'),
#  ('YearRemodAdd', 'KitchenAbvGr', 'GarageCars'),
#  ('YearRemodAdd', 'KitchenAbvGr', 'GarageArea'),
#  ('YearRemodAdd', 'BedroomAbvGr', 'LotArea'),
#  ('YearRemodAdd', 'BedroomAbvGr', 'YearBuilt'),
#  ('YearRemodAdd', 'BedroomAbvGr', 'first'),
#  ('YearRemodAdd', 'BedroomAbvGr', 'second'),
#  ('YearRemodAdd', 'BedroomAbvGr', 'TotRmsAbvGrd'),
#  ('YearRemodAdd', 'BedroomAbvGr', 'KitchenAbvGr'),
#  ('YearRemodAdd', 'BedroomAbvGr', 'GarageCars'),
#  ('YearRemodAdd', 'BedroomAbvGr', 'GarageArea'),
#  ('YearRemodAdd', 'GarageCars', 'LotArea'),
#  ('YearRemodAdd', 'GarageCars', 'YearBuilt'),
#  ('YearRemodAdd', 'GarageCars', 'first'),
#  ('YearRemodAdd', 'GarageCars', 'second'),
#  ('YearRemodAdd', 'GarageCars', 'TotRmsAbvGrd'),
#  ('YearRemodAdd', 'GarageCars', 'KitchenAbvGr'),
#  ('YearRemodAdd', 'GarageCars', 'BedroomAbvGr'),
#  ('YearRemodAdd', 'GarageCars', 'GarageArea'),
#  ('YearRemodAdd', 'GarageArea', 'LotArea'),
#  ('YearRemodAdd', 'GarageArea', 'YearBuilt'),
#  ('YearRemodAdd', 'GarageArea', 'first'),
#  ('YearRemodAdd', 'GarageArea', 'second'),
#  ('YearRemodAdd', 'GarageArea', 'TotRmsAbvGrd'),
#  ('YearRemodAdd', 'GarageArea', 'KitchenAbvGr'),
#  ('YearRemodAdd', 'GarageArea', 'BedroomAbvGr'),
#  ('YearRemodAdd', 'GarageArea', 'GarageCars'),
#  ('TotRmsAbvGrd', 'LotArea', 'YearBuilt'),
#  ('TotRmsAbvGrd', 'LotArea', 'first'),
#  ('TotRmsAbvGrd', 'LotArea', 'second'),
#  ('TotRmsAbvGrd', 'LotArea', 'YearRemodAdd'),
#  ('TotRmsAbvGrd', 'LotArea', 'KitchenAbvGr'),
#  ('TotRmsAbvGrd', 'LotArea', 'BedroomAbvGr'),
#  ('TotRmsAbvGrd', 'LotArea', 'GarageCars'),
#  ('TotRmsAbvGrd', 'LotArea', 'GarageArea'),
#  ('TotRmsAbvGrd', 'YearBuilt', 'LotArea'),
#  ('TotRmsAbvGrd', 'YearBuilt', 'first'),
#  ('TotRmsAbvGrd', 'YearBuilt', 'second'),
#  ('TotRmsAbvGrd', 'YearBuilt', 'YearRemodAdd'),
#  ('TotRmsAbvGrd', 'YearBuilt', 'KitchenAbvGr'),
#  ('TotRmsAbvGrd', 'YearBuilt', 'BedroomAbvGr'),
#  ('TotRmsAbvGrd', 'YearBuilt', 'GarageCars'),
#  ('TotRmsAbvGrd', 'YearBuilt', 'GarageArea'),
#  ('TotRmsAbvGrd', 'first', 'LotArea'),
#  ('TotRmsAbvGrd', 'first', 'YearBuilt'),
#  ('TotRmsAbvGrd', 'first', 'second'),
#  ('TotRmsAbvGrd', 'first', 'YearRemodAdd'),
#  ('TotRmsAbvGrd', 'first', 'KitchenAbvGr'),
#  ('TotRmsAbvGrd', 'first', 'BedroomAbvGr'),
#  ('TotRmsAbvGrd', 'first', 'GarageCars'),
#  ('TotRmsAbvGrd', 'first', 'GarageArea'),
#  ('TotRmsAbvGrd', 'second', 'LotArea'),
#  ('TotRmsAbvGrd', 'second', 'YearBuilt'),
#  ('TotRmsAbvGrd', 'second', 'first'),
#  ('TotRmsAbvGrd', 'second', 'YearRemodAdd'),
#  ('TotRmsAbvGrd', 'second', 'KitchenAbvGr'),
#  ('TotRmsAbvGrd', 'second', 'BedroomAbvGr'),
#  ('TotRmsAbvGrd', 'second', 'GarageCars'),
#  ('TotRmsAbvGrd', 'second', 'GarageArea'),
#  ('TotRmsAbvGrd', 'YearRemodAdd', 'LotArea'),
#  ('TotRmsAbvGrd', 'YearRemodAdd', 'YearBuilt'),
#  ('TotRmsAbvGrd', 'YearRemodAdd', 'first'),
#  ('TotRmsAbvGrd', 'YearRemodAdd', 'second'),
#  ('TotRmsAbvGrd', 'YearRemodAdd', 'KitchenAbvGr'),
#  ('TotRmsAbvGrd', 'YearRemodAdd', 'BedroomAbvGr'),
#  ('TotRmsAbvGrd', 'YearRemodAdd', 'GarageCars'),
#  ('TotRmsAbvGrd', 'YearRemodAdd', 'GarageArea'),
#  ('TotRmsAbvGrd', 'KitchenAbvGr', 'LotArea'),
#  ('TotRmsAbvGrd', 'KitchenAbvGr', 'YearBuilt'),
#  ('TotRmsAbvGrd', 'KitchenAbvGr', 'first'),
#  ('TotRmsAbvGrd', 'KitchenAbvGr', 'second'),
#  ('TotRmsAbvGrd', 'KitchenAbvGr', 'YearRemodAdd'),
#  ('TotRmsAbvGrd', 'KitchenAbvGr', 'BedroomAbvGr'),
#  ('TotRmsAbvGrd', 'KitchenAbvGr', 'GarageCars'),
#  ('TotRmsAbvGrd', 'KitchenAbvGr', 'GarageArea'),
#  ('TotRmsAbvGrd', 'BedroomAbvGr', 'LotArea'),
#  ('TotRmsAbvGrd', 'BedroomAbvGr', 'YearBuilt'),
#  ('TotRmsAbvGrd', 'BedroomAbvGr', 'first'),
#  ('TotRmsAbvGrd', 'BedroomAbvGr', 'second'),
#  ('TotRmsAbvGrd', 'BedroomAbvGr', 'YearRemodAdd'),
#  ('TotRmsAbvGrd', 'BedroomAbvGr', 'KitchenAbvGr'),
#  ('TotRmsAbvGrd', 'BedroomAbvGr', 'GarageCars'),
#  ('TotRmsAbvGrd', 'BedroomAbvGr', 'GarageArea'),
#  ('TotRmsAbvGrd', 'GarageCars', 'LotArea'),
#  ('TotRmsAbvGrd', 'GarageCars', 'YearBuilt'),
#  ('TotRmsAbvGrd', 'GarageCars', 'first'),
#  ('TotRmsAbvGrd', 'GarageCars', 'second'),
#  ('TotRmsAbvGrd', 'GarageCars', 'YearRemodAdd'),
#  ('TotRmsAbvGrd', 'GarageCars', 'KitchenAbvGr'),
#  ('TotRmsAbvGrd', 'GarageCars', 'BedroomAbvGr'),
#  ('TotRmsAbvGrd', 'GarageCars', 'GarageArea'),
#  ('TotRmsAbvGrd', 'GarageArea', 'LotArea'),
#  ('TotRmsAbvGrd', 'GarageArea', 'YearBuilt'),
#  ('TotRmsAbvGrd', 'GarageArea', 'first'),
#  ('TotRmsAbvGrd', 'GarageArea', 'second'),
#  ('TotRmsAbvGrd', 'GarageArea', 'YearRemodAdd'),
#  ('TotRmsAbvGrd', 'GarageArea', 'KitchenAbvGr'),
#  ('TotRmsAbvGrd', 'GarageArea', 'BedroomAbvGr'),
#  ('TotRmsAbvGrd', 'GarageArea', 'GarageCars'),
#  ('KitchenAbvGr', 'LotArea', 'YearBuilt'),
#  ('KitchenAbvGr', 'LotArea', 'first'),
#  ('KitchenAbvGr', 'LotArea', 'second'),
#  ('KitchenAbvGr', 'LotArea', 'YearRemodAdd'),
#  ('KitchenAbvGr', 'LotArea', 'TotRmsAbvGrd'),
#  ('KitchenAbvGr', 'LotArea', 'BedroomAbvGr'),
#  ('KitchenAbvGr', 'LotArea', 'GarageCars'),
#  ('KitchenAbvGr', 'LotArea', 'GarageArea'),
#  ('KitchenAbvGr', 'YearBuilt', 'LotArea'),
#  ('KitchenAbvGr', 'YearBuilt', 'first'),
#  ('KitchenAbvGr', 'YearBuilt', 'second'),
#  ('KitchenAbvGr', 'YearBuilt', 'YearRemodAdd'),
#  ('KitchenAbvGr', 'YearBuilt', 'TotRmsAbvGrd'),
#  ('KitchenAbvGr', 'YearBuilt', 'BedroomAbvGr'),
#  ('KitchenAbvGr', 'YearBuilt', 'GarageCars'),
#  ('KitchenAbvGr', 'YearBuilt', 'GarageArea'),
#  ('KitchenAbvGr', 'first', 'LotArea'),
#  ('KitchenAbvGr', 'first', 'YearBuilt'),
#  ('KitchenAbvGr', 'first', 'second'),
#  ('KitchenAbvGr', 'first', 'YearRemodAdd'),
#  ('KitchenAbvGr', 'first', 'TotRmsAbvGrd'),
#  ('KitchenAbvGr', 'first', 'BedroomAbvGr'),
#  ('KitchenAbvGr', 'first', 'GarageCars'),
#  ('KitchenAbvGr', 'first', 'GarageArea'),
#  ('KitchenAbvGr', 'second', 'LotArea'),
#  ('KitchenAbvGr', 'second', 'YearBuilt'),
#  ('KitchenAbvGr', 'second', 'first'),
#  ('KitchenAbvGr', 'second', 'YearRemodAdd'),
#  ('KitchenAbvGr', 'second', 'TotRmsAbvGrd'),
#  ('KitchenAbvGr', 'second', 'BedroomAbvGr'),
#  ('KitchenAbvGr', 'second', 'GarageCars'),
#  ('KitchenAbvGr', 'second', 'GarageArea'),
#  ('KitchenAbvGr', 'YearRemodAdd', 'LotArea'),
#  ('KitchenAbvGr', 'YearRemodAdd', 'YearBuilt'),
#  ('KitchenAbvGr', 'YearRemodAdd', 'first'),
#  ('KitchenAbvGr', 'YearRemodAdd', 'second'),
#  ('KitchenAbvGr', 'YearRemodAdd', 'TotRmsAbvGrd'),
#  ('KitchenAbvGr', 'YearRemodAdd', 'BedroomAbvGr'),
#  ('KitchenAbvGr', 'YearRemodAdd', 'GarageCars'),
#  ('KitchenAbvGr', 'YearRemodAdd', 'GarageArea'),
#  ('KitchenAbvGr', 'TotRmsAbvGrd', 'LotArea'),
#  ('KitchenAbvGr', 'TotRmsAbvGrd', 'YearBuilt'),
#  ('KitchenAbvGr', 'TotRmsAbvGrd', 'first'),
#  ('KitchenAbvGr', 'TotRmsAbvGrd', 'second'),
#  ('KitchenAbvGr', 'TotRmsAbvGrd', 'YearRemodAdd'),
#  ('KitchenAbvGr', 'TotRmsAbvGrd', 'BedroomAbvGr'),
#  ('KitchenAbvGr', 'TotRmsAbvGrd', 'GarageCars'),
#  ('KitchenAbvGr', 'TotRmsAbvGrd', 'GarageArea'),
#  ('KitchenAbvGr', 'BedroomAbvGr', 'LotArea'),
#  ('KitchenAbvGr', 'BedroomAbvGr', 'YearBuilt'),
#  ('KitchenAbvGr', 'BedroomAbvGr', 'first'),
#  ('KitchenAbvGr', 'BedroomAbvGr', 'second'),
#  ('KitchenAbvGr', 'BedroomAbvGr', 'YearRemodAdd'),
#  ('KitchenAbvGr', 'BedroomAbvGr', 'TotRmsAbvGrd'),
#  ('KitchenAbvGr', 'BedroomAbvGr', 'GarageCars'),
#  ('KitchenAbvGr', 'BedroomAbvGr', 'GarageArea'),
#  ('KitchenAbvGr', 'GarageCars', 'LotArea'),
#  ('KitchenAbvGr', 'GarageCars', 'YearBuilt'),
#  ('KitchenAbvGr', 'GarageCars', 'first'),
#  ('KitchenAbvGr', 'GarageCars', 'second'),
#  ('KitchenAbvGr', 'GarageCars', 'YearRemodAdd'),
#  ('KitchenAbvGr', 'GarageCars', 'TotRmsAbvGrd'),
#  ('KitchenAbvGr', 'GarageCars', 'BedroomAbvGr'),
#  ('KitchenAbvGr', 'GarageCars', 'GarageArea'),
#  ('KitchenAbvGr', 'GarageArea', 'LotArea'),
#  ('KitchenAbvGr', 'GarageArea', 'YearBuilt'),
#  ('KitchenAbvGr', 'GarageArea', 'first'),
#  ('KitchenAbvGr', 'GarageArea', 'second'),
#  ('KitchenAbvGr', 'GarageArea', 'YearRemodAdd'),
#  ('KitchenAbvGr', 'GarageArea', 'TotRmsAbvGrd'),
#  ('KitchenAbvGr', 'GarageArea', 'BedroomAbvGr'),
#  ('KitchenAbvGr', 'GarageArea', 'GarageCars'),
#  ('BedroomAbvGr', 'LotArea', 'YearBuilt'),
#  ('BedroomAbvGr', 'LotArea', 'first'),
#  ('BedroomAbvGr', 'LotArea', 'second'),
#  ('BedroomAbvGr', 'LotArea', 'YearRemodAdd'),
#  ('BedroomAbvGr', 'LotArea', 'TotRmsAbvGrd'),
#  ('BedroomAbvGr', 'LotArea', 'KitchenAbvGr'),
#  ('BedroomAbvGr', 'LotArea', 'GarageCars'),
#  ('BedroomAbvGr', 'LotArea', 'GarageArea'),
#  ('BedroomAbvGr', 'YearBuilt', 'LotArea'),
#  ('BedroomAbvGr', 'YearBuilt', 'first'),
#  ('BedroomAbvGr', 'YearBuilt', 'second'),
#  ('BedroomAbvGr', 'YearBuilt', 'YearRemodAdd'),
#  ('BedroomAbvGr', 'YearBuilt', 'TotRmsAbvGrd'),
#  ('BedroomAbvGr', 'YearBuilt', 'KitchenAbvGr'),
#  ('BedroomAbvGr', 'YearBuilt', 'GarageCars'),
#  ('BedroomAbvGr', 'YearBuilt', 'GarageArea'),
#  ('BedroomAbvGr', 'first', 'LotArea'),
#  ('BedroomAbvGr', 'first', 'YearBuilt'),
#  ('BedroomAbvGr', 'first', 'second'),
#  ('BedroomAbvGr', 'first', 'YearRemodAdd'),
#  ('BedroomAbvGr', 'first', 'TotRmsAbvGrd'),
#  ('BedroomAbvGr', 'first', 'KitchenAbvGr'),
#  ('BedroomAbvGr', 'first', 'GarageCars'),
#  ('BedroomAbvGr', 'first', 'GarageArea'),
#  ('BedroomAbvGr', 'second', 'LotArea'),
#  ('BedroomAbvGr', 'second', 'YearBuilt'),
#  ('BedroomAbvGr', 'second', 'first'),
#  ('BedroomAbvGr', 'second', 'YearRemodAdd'),
#  ('BedroomAbvGr', 'second', 'TotRmsAbvGrd'),
#  ('BedroomAbvGr', 'second', 'KitchenAbvGr'),
#  ('BedroomAbvGr', 'second', 'GarageCars'),
#  ('BedroomAbvGr', 'second', 'GarageArea'),
#  ('BedroomAbvGr', 'YearRemodAdd', 'LotArea'),
#  ('BedroomAbvGr', 'YearRemodAdd', 'YearBuilt'),
#  ('BedroomAbvGr', 'YearRemodAdd', 'first'),
#  ('BedroomAbvGr', 'YearRemodAdd', 'second'),
#  ('BedroomAbvGr', 'YearRemodAdd', 'TotRmsAbvGrd'),
#  ('BedroomAbvGr', 'YearRemodAdd', 'KitchenAbvGr'),
#  ('BedroomAbvGr', 'YearRemodAdd', 'GarageCars'),
#  ('BedroomAbvGr', 'YearRemodAdd', 'GarageArea'),
#  ('BedroomAbvGr', 'TotRmsAbvGrd', 'LotArea'),
#  ('BedroomAbvGr', 'TotRmsAbvGrd', 'YearBuilt'),
#  ('BedroomAbvGr', 'TotRmsAbvGrd', 'first'),
#  ('BedroomAbvGr', 'TotRmsAbvGrd', 'second'),
#  ('BedroomAbvGr', 'TotRmsAbvGrd', 'YearRemodAdd'),
#  ('BedroomAbvGr', 'TotRmsAbvGrd', 'KitchenAbvGr'),
#  ('BedroomAbvGr', 'TotRmsAbvGrd', 'GarageCars'),
#  ('BedroomAbvGr', 'TotRmsAbvGrd', 'GarageArea'),
#  ('BedroomAbvGr', 'KitchenAbvGr', 'LotArea'),
#  ('BedroomAbvGr', 'KitchenAbvGr', 'YearBuilt'),
#  ('BedroomAbvGr', 'KitchenAbvGr', 'first'),
#  ('BedroomAbvGr', 'KitchenAbvGr', 'second'),
#  ('BedroomAbvGr', 'KitchenAbvGr', 'YearRemodAdd'),
#  ('BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd'),
#  ('BedroomAbvGr', 'KitchenAbvGr', 'GarageCars'),
#  ('BedroomAbvGr', 'KitchenAbvGr', 'GarageArea'),
#  ('BedroomAbvGr', 'GarageCars', 'LotArea'),
#  ('BedroomAbvGr', 'GarageCars', 'YearBuilt'),
#  ('BedroomAbvGr', 'GarageCars', 'first'),
#  ('BedroomAbvGr', 'GarageCars', 'second'),
#  ('BedroomAbvGr', 'GarageCars', 'YearRemodAdd'),
#  ('BedroomAbvGr', 'GarageCars', 'TotRmsAbvGrd'),
#  ('BedroomAbvGr', 'GarageCars', 'KitchenAbvGr'),
#  ('BedroomAbvGr', 'GarageCars', 'GarageArea'),
#  ('BedroomAbvGr', 'GarageArea', 'LotArea'),
#  ('BedroomAbvGr', 'GarageArea', 'YearBuilt'),
#  ('BedroomAbvGr', 'GarageArea', 'first'),
#  ('BedroomAbvGr', 'GarageArea', 'second'),
#  ('BedroomAbvGr', 'GarageArea', 'YearRemodAdd'),
#  ('BedroomAbvGr', 'GarageArea', 'TotRmsAbvGrd'),
#  ('BedroomAbvGr', 'GarageArea', 'KitchenAbvGr'),
#  ('BedroomAbvGr', 'GarageArea', 'GarageCars'),
#  ('GarageCars', 'LotArea', 'YearBuilt'),
#  ('GarageCars', 'LotArea', 'first'),
#  ('GarageCars', 'LotArea', 'second'),
#  ('GarageCars', 'LotArea', 'YearRemodAdd'),
#  ('GarageCars', 'LotArea', 'TotRmsAbvGrd'),
#  ('GarageCars', 'LotArea', 'KitchenAbvGr'),
#  ('GarageCars', 'LotArea', 'BedroomAbvGr'),
#  ('GarageCars', 'LotArea', 'GarageArea'),
#  ('GarageCars', 'YearBuilt', 'LotArea'),
#  ('GarageCars', 'YearBuilt', 'first'),
#  ('GarageCars', 'YearBuilt', 'second'),
#  ('GarageCars', 'YearBuilt', 'YearRemodAdd'),
#  ('GarageCars', 'YearBuilt', 'TotRmsAbvGrd'),
#  ('GarageCars', 'YearBuilt', 'KitchenAbvGr'),
#  ('GarageCars', 'YearBuilt', 'BedroomAbvGr'),
#  ('GarageCars', 'YearBuilt', 'GarageArea'),
#  ('GarageCars', 'first', 'LotArea'),
#  ('GarageCars', 'first', 'YearBuilt'),
#  ('GarageCars', 'first', 'second'),
#  ('GarageCars', 'first', 'YearRemodAdd'),
#  ('GarageCars', 'first', 'TotRmsAbvGrd'),
#  ('GarageCars', 'first', 'KitchenAbvGr'),
#  ('GarageCars', 'first', 'BedroomAbvGr'),
#  ('GarageCars', 'first', 'GarageArea'),
#  ('GarageCars', 'second', 'LotArea'),
#  ('GarageCars', 'second', 'YearBuilt'),
#  ('GarageCars', 'second', 'first'),
#  ('GarageCars', 'second', 'YearRemodAdd'),
#  ('GarageCars', 'second', 'TotRmsAbvGrd'),
#  ('GarageCars', 'second', 'KitchenAbvGr'),
#  ('GarageCars', 'second', 'BedroomAbvGr'),
#  ('GarageCars', 'second', 'GarageArea'),
#  ('GarageCars', 'YearRemodAdd', 'LotArea'),
#  ('GarageCars', 'YearRemodAdd', 'YearBuilt'),
#  ('GarageCars', 'YearRemodAdd', 'first'),
#  ('GarageCars', 'YearRemodAdd', 'second'),
#  ('GarageCars', 'YearRemodAdd', 'TotRmsAbvGrd'),
#  ('GarageCars', 'YearRemodAdd', 'KitchenAbvGr'),
#  ('GarageCars', 'YearRemodAdd', 'BedroomAbvGr'),
#  ('GarageCars', 'YearRemodAdd', 'GarageArea'),
#  ('GarageCars', 'TotRmsAbvGrd', 'LotArea'),
#  ('GarageCars', 'TotRmsAbvGrd', 'YearBuilt'),
#  ('GarageCars', 'TotRmsAbvGrd', 'first'),
#  ('GarageCars', 'TotRmsAbvGrd', 'second'),
#  ('GarageCars', 'TotRmsAbvGrd', 'YearRemodAdd'),
#  ('GarageCars', 'TotRmsAbvGrd', 'KitchenAbvGr'),
#  ('GarageCars', 'TotRmsAbvGrd', 'BedroomAbvGr'),
#  ('GarageCars', 'TotRmsAbvGrd', 'GarageArea'),
#  ('GarageCars', 'KitchenAbvGr', 'LotArea'),
#  ('GarageCars', 'KitchenAbvGr', 'YearBuilt'),
#  ('GarageCars', 'KitchenAbvGr', 'first'),
#  ('GarageCars', 'KitchenAbvGr', 'second'),
#  ('GarageCars', 'KitchenAbvGr', 'YearRemodAdd'),
#  ('GarageCars', 'KitchenAbvGr', 'TotRmsAbvGrd'),
#  ('GarageCars', 'KitchenAbvGr', 'BedroomAbvGr'),
#  ('GarageCars', 'KitchenAbvGr', 'GarageArea'),
#  ('GarageCars', 'BedroomAbvGr', 'LotArea'),
#  ('GarageCars', 'BedroomAbvGr', 'YearBuilt'),
#  ('GarageCars', 'BedroomAbvGr', 'first'),
#  ('GarageCars', 'BedroomAbvGr', 'second'),
#  ('GarageCars', 'BedroomAbvGr', 'YearRemodAdd'),
#  ('GarageCars', 'BedroomAbvGr', 'TotRmsAbvGrd'),
#  ('GarageCars', 'BedroomAbvGr', 'KitchenAbvGr'),
#  ('GarageCars', 'BedroomAbvGr', 'GarageArea'),
#  ('GarageCars', 'GarageArea', 'LotArea'),
#  ('GarageCars', 'GarageArea', 'YearBuilt'),
#  ('GarageCars', 'GarageArea', 'first'),
#  ('GarageCars', 'GarageArea', 'second'),
#  ('GarageCars', 'GarageArea', 'YearRemodAdd'),
#  ('GarageCars', 'GarageArea', 'TotRmsAbvGrd'),
#  ('GarageCars', 'GarageArea', 'KitchenAbvGr'),
#  ('GarageCars', 'GarageArea', 'BedroomAbvGr'),
#  ('GarageArea', 'LotArea', 'YearBuilt'),
#  ('GarageArea', 'LotArea', 'first'),
#  ('GarageArea', 'LotArea', 'second'),
#  ('GarageArea', 'LotArea', 'YearRemodAdd'),
#  ('GarageArea', 'LotArea', 'TotRmsAbvGrd'),
#  ('GarageArea', 'LotArea', 'KitchenAbvGr'),
#  ('GarageArea', 'LotArea', 'BedroomAbvGr'),
#  ('GarageArea', 'LotArea', 'GarageCars'),
#  ('GarageArea', 'YearBuilt', 'LotArea'),
#  ('GarageArea', 'YearBuilt', 'first'),
#  ('GarageArea', 'YearBuilt', 'second'),
#  ('GarageArea', 'YearBuilt', 'YearRemodAdd'),
#  ('GarageArea', 'YearBuilt', 'TotRmsAbvGrd'),
#  ('GarageArea', 'YearBuilt', 'KitchenAbvGr'),
#  ('GarageArea', 'YearBuilt', 'BedroomAbvGr'),
#  ('GarageArea', 'YearBuilt', 'GarageCars'),
#  ('GarageArea', 'first', 'LotArea'),
#  ('GarageArea', 'first', 'YearBuilt'),
#  ('GarageArea', 'first', 'second'),
#  ('GarageArea', 'first', 'YearRemodAdd'),
#  ('GarageArea', 'first', 'TotRmsAbvGrd'),
#  ('GarageArea', 'first', 'KitchenAbvGr'),
#  ('GarageArea', 'first', 'BedroomAbvGr'),
#  ('GarageArea', 'first', 'GarageCars'),
#  ('GarageArea', 'second', 'LotArea'),
#  ('GarageArea', 'second', 'YearBuilt'),
#  ('GarageArea', 'second', 'first'),
#  ('GarageArea', 'second', 'YearRemodAdd'),
#  ('GarageArea', 'second', 'TotRmsAbvGrd'),
#  ('GarageArea', 'second', 'KitchenAbvGr'),
#  ('GarageArea', 'second', 'BedroomAbvGr'),
#  ('GarageArea', 'second', 'GarageCars'),
#  ('GarageArea', 'YearRemodAdd', 'LotArea'),
#  ('GarageArea', 'YearRemodAdd', 'YearBuilt'),
#  ('GarageArea', 'YearRemodAdd', 'first'),
#  ('GarageArea', 'YearRemodAdd', 'second'),
#  ('GarageArea', 'YearRemodAdd', 'TotRmsAbvGrd'),
#  ('GarageArea', 'YearRemodAdd', 'KitchenAbvGr'),
#  ('GarageArea', 'YearRemodAdd', 'BedroomAbvGr'),
#  ('GarageArea', 'YearRemodAdd', 'GarageCars'),
#  ('GarageArea', 'TotRmsAbvGrd', 'LotArea'),
#  ('GarageArea', 'TotRmsAbvGrd', 'YearBuilt'),
#  ('GarageArea', 'TotRmsAbvGrd', 'first'),
#  ('GarageArea', 'TotRmsAbvGrd', 'second'),
#  ('GarageArea', 'TotRmsAbvGrd', 'YearRemodAdd'),
#  ('GarageArea', 'TotRmsAbvGrd', 'KitchenAbvGr'),
#  ('GarageArea', 'TotRmsAbvGrd', 'BedroomAbvGr'),
#  ('GarageArea', 'TotRmsAbvGrd', 'GarageCars'),
#  ('GarageArea', 'KitchenAbvGr', 'LotArea'),
#  ('GarageArea', 'KitchenAbvGr', 'YearBuilt'),
#  ('GarageArea', 'KitchenAbvGr', 'first'),
#  ('GarageArea', 'KitchenAbvGr', 'second'),
#  ('GarageArea', 'KitchenAbvGr', 'YearRemodAdd'),
#  ('GarageArea', 'KitchenAbvGr', 'TotRmsAbvGrd'),
#  ('GarageArea', 'KitchenAbvGr', 'BedroomAbvGr'),
#  ('GarageArea', 'KitchenAbvGr', 'GarageCars'),
#  ('GarageArea', 'BedroomAbvGr', 'LotArea'),
#  ('GarageArea', 'BedroomAbvGr', 'YearBuilt'),
#  ('GarageArea', 'BedroomAbvGr', 'first'),
#  ('GarageArea', 'BedroomAbvGr', 'second'),
#  ('GarageArea', 'BedroomAbvGr', 'YearRemodAdd'),
#  ('GarageArea', 'BedroomAbvGr', 'TotRmsAbvGrd'),
#  ('GarageArea', 'BedroomAbvGr', 'KitchenAbvGr'),
#  ('GarageArea', 'BedroomAbvGr', 'GarageCars'),
#  ('GarageArea', 'GarageCars', 'LotArea'),
#  ('GarageArea', 'GarageCars', 'YearBuilt'),
#  ('GarageArea', 'GarageCars', 'first'),
#  ('GarageArea', 'GarageCars', 'second'),
#  ('GarageArea', 'GarageCars', 'YearRemodAdd'),
#  ('GarageArea', 'GarageCars', 'TotRmsAbvGrd'),
#  ('GarageArea', 'GarageCars', 'KitchenAbvGr'),
#  ('GarageArea', 'GarageCars', 'BedroomAbvGr')]

# %%
#':'로 붙임(?)
variables= '+ '.join(list(X_train.columns)) +'+'+ '+'.join([':'.join(list(y)) for y in comb])

# %%
'+ '.join(list(X_train.columns))
'+'.join([':'.join(list(y)) for y in comb])
variables
# Out:
# 'LotArea+ YearBuilt+ first+ second+ YearRemodAdd+ TotRmsAbvGrd+ KitchenAbvGr+ BedroomAbvGr+ GarageCars+ GarageArea+LotArea:YearBuilt:first+LotArea:YearBuilt:second+LotArea:YearBuilt:YearRemodAdd+LotArea:YearBuilt:TotRmsAbvGrd+LotArea:YearBuilt:KitchenAbvGr+LotArea:YearBuilt:BedroomAbvGr+LotArea:YearBuilt:GarageCars+LotArea:YearBuilt:GarageArea+LotArea:first:YearBuilt+LotArea:first:second+LotArea:first:YearRemodAdd+LotArea:first:TotRmsAbvGrd+LotArea:first:KitchenAbvGr+LotArea:first:BedroomAbvGr+LotArea:first:GarageCars+LotArea:first:GarageArea+LotArea:second:YearBuilt+LotArea:second:first+LotArea:second:YearRemodAdd+LotArea:second:TotRmsAbvGrd+LotArea:second:KitchenAbvGr+LotArea:second:BedroomAbvGr+LotArea:second:GarageCars+LotArea:second:GarageArea+LotArea:YearRemodAdd:YearBuilt+LotArea:YearRemodAdd:first+LotArea:YearRemodAdd:second+LotArea:YearRemodAdd:TotRmsAbvGrd+LotArea:YearRemodAdd:KitchenAbvGr+LotArea:YearRemodAdd:BedroomAbvGr+LotArea:YearRemodAdd:GarageCars+LotArea:YearRemodAdd:GarageArea+LotArea:TotRmsAbvGrd:YearBuilt+LotArea:TotRmsAbvGrd:first+LotArea:TotRmsAbvGrd:second+LotArea:TotRmsAbvGrd:YearRemodAdd+LotArea:TotRmsAbvGrd:KitchenAbvGr+LotArea:TotRmsAbvGrd:BedroomAbvGr+LotArea:TotRmsAbvGrd:GarageCars+LotArea:TotRmsAbvGrd:GarageArea+LotArea:KitchenAbvGr:YearBuilt+LotArea:KitchenAbvGr:first+LotArea:KitchenAbvGr:second+LotArea:KitchenAbvGr:YearRemodAdd+LotArea:KitchenAbvGr:TotRmsAbvGrd+LotArea:KitchenAbvGr:BedroomAbvGr+LotArea:KitchenAbvGr:GarageCars+LotArea:KitchenAbvGr:GarageArea+LotArea:BedroomAbvGr:YearBuilt+LotArea:BedroomAbvGr:first+LotArea:BedroomAbvGr:second+LotArea:BedroomAbvGr:YearRemodAdd+LotArea:BedroomAbvGr:TotRmsAbvGrd+LotArea:BedroomAbvGr:KitchenAbvGr+LotArea:BedroomAbvGr:GarageCars+LotArea:BedroomAbvGr:GarageArea+LotArea:GarageCars:YearBuilt+LotArea:GarageCars:first+LotArea:GarageCars:second+LotArea:GarageCars:YearRemodAdd+LotArea:GarageCars:TotRmsAbvGrd+LotArea:GarageCars:KitchenAbvGr+LotArea:GarageCars:BedroomAbvGr+LotArea:GarageCars:GarageArea+LotArea:GarageArea:YearBuilt+LotArea:GarageArea:first+LotArea:GarageArea:second+LotArea:GarageArea:YearRemodAdd+LotArea:GarageArea:TotRmsAbvGrd+LotArea:GarageArea:KitchenAbvGr+LotArea:GarageArea:BedroomAbvGr+LotArea:GarageArea:GarageCars+YearBuilt:LotArea:first+YearBuilt:LotArea:second+YearBuilt:LotArea:YearRemodAdd+YearBuilt:LotArea:TotRmsAbvGrd+YearBuilt:LotArea:KitchenAbvGr+YearBuilt:LotArea:BedroomAbvGr+YearBuilt:LotArea:GarageCars+YearBuilt:LotArea:GarageArea+YearBuilt:first:LotArea+YearBuilt:first:second+YearBuilt:first:YearRemodAdd+YearBuilt:first:TotRmsAbvGrd+YearBuilt:first:KitchenAbvGr+YearBuilt:first:BedroomAbvGr+YearBuilt:first:GarageCars+YearBuilt:first:GarageArea+YearBuilt:second:LotArea+YearBuilt:second:first+YearBuilt:second:YearRemodAdd+YearBuilt:second:TotRmsAbvGrd+YearBuilt:second:KitchenAbvGr+YearBuilt:second:BedroomAbvGr+YearBuilt:second:GarageCars+YearBuilt:second:GarageArea+YearBuilt:YearRemodAdd:LotArea+YearBuilt:YearRemodAdd:first+YearBuilt:YearRemodAdd:second+YearBuilt:YearRemodAdd:TotRmsAbvGrd+YearBuilt:YearRemodAdd:KitchenAbvGr+YearBuilt:YearRemodAdd:BedroomAbvGr+YearBuilt:YearRemodAdd:GarageCars+YearBuilt:YearRemodAdd:GarageArea+YearBuilt:TotRmsAbvGrd:LotArea+YearBuilt:TotRmsAbvGrd:first+YearBuilt:TotRmsAbvGrd:second+YearBuilt:TotRmsAbvGrd:YearRemodAdd+YearBuilt:TotRmsAbvGrd:KitchenAbvGr+YearBuilt:TotRmsAbvGrd:BedroomAbvGr+YearBuilt:TotRmsAbvGrd:GarageCars+YearBuilt:TotRmsAbvGrd:GarageArea+YearBuilt:KitchenAbvGr:LotArea+YearBuilt:KitchenAbvGr:first+YearBuilt:KitchenAbvGr:second+YearBuilt:KitchenAbvGr:YearRemodAdd+YearBuilt:KitchenAbvGr:TotRmsAbvGrd+YearBuilt:KitchenAbvGr:BedroomAbvGr+YearBuilt:KitchenAbvGr:GarageCars+YearBuilt:KitchenAbvGr:GarageArea+YearBuilt:BedroomAbvGr:LotArea+YearBuilt:BedroomAbvGr:first+YearBuilt:BedroomAbvGr:second+YearBuilt:BedroomAbvGr:YearRemodAdd+YearBuilt:BedroomAbvGr:TotRmsAbvGrd+YearBuilt:BedroomAbvGr:KitchenAbvGr+YearBuilt:BedroomAbvGr:GarageCars+YearBuilt:BedroomAbvGr:GarageArea+YearBuilt:GarageCars: ...

# %%
from statsmodels.formula.api import ols

res=ols(f'price~{variables}', data=pd.concat([X_train, y_train], axis=1)).fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.885
# Model:                            OLS   Adj. R-squared:                  0.869
# Method:                 Least Squares   F-statistic:                     57.03
# Date:                Mon, 12 Sep 2022   Prob (F-statistic):               0.00
# Time:                        17:49:46   Log-Likelihood:                 604.28
# No. Observations:                1095   AIC:                            -946.6
# Df Residuals:                     964   BIC:                            -291.8
# Df Model:                         130
# Covariance Type:            nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                                 11.1537      0.146     76.330      0.000      10.867      11.440
# LotArea                                 1.715e-05   5.26e-06      3.259      0.001    6.82e-06    2.75e-05
# YearBuilt                                 -0.0039      0.001     -4.408      0.000      -0.006      -0.002
# first                                      0.0008      0.000      6.324      0.000       0.001       0.001
# second                                     0.0005      0.000      4.878      0.000       0.000       0.001
# YearRemodAdd                              -0.0008      0.001     -0.573      0.567      -0.004       0.002
# TotRmsAbvGrd                               0.0160      0.027      0.590      0.555      -0.037       0.069
# KitchenAbvGr                              -0.2305      0.131     -1.758      0.079      -0.488       0.027
# BedroomAbvGr                              -0.0360      0.032     -1.130      0.259      -0.099       0.027
# GarageCars                                -0.0416      0.069     -0.599      0.549      -0.178       0.095
# GarageArea                                 0.0008      0.000      3.205      0.001       0.000       0.001
# LotArea:YearBuilt:first                -1.358e-10   2.13e-10     -0.637      0.524   -5.54e-10    2.83e-10
# LotArea:YearBuilt:second                1.525e-10   2.44e-10      0.625      0.532   -3.26e-10    6.31e-10
# LotArea:YearBuilt:YearRemodAdd         -4.612e-09   3.06e-09     -1.507      0.132   -1.06e-08    1.39e-09
# LotArea:YearBuilt:TotRmsAbvGrd          9.195e-08   6.34e-08      1.450      0.147   -3.25e-08    2.16e-07
# LotArea:YearBuilt:KitchenAbvGr          7.674e-08   2.76e-07      0.278      0.781   -4.64e-07    6.18e-07
# LotArea:YearBuilt:BedroomAbvGr         -1.306e-07   1.14e-07     -1.149      0.251   -3.54e-07    9.25e-08
# LotArea:YearBuilt:GarageCars           -9.988e-08    1.9e-07     -0.526      0.599   -4.72e-07    2.73e-07
# LotArea:YearBuilt:GarageArea           -8.831e-11   6.29e-10     -0.140      0.888   -1.32e-09    1.15e-09
# LotArea:first:second                   -3.216e-11   1.08e-11     -2.983      0.003   -5.33e-11    -1.1e-11
# LotArea:first:YearRemodAdd             -7.201e-10   2.82e-10     -2.550      0.011   -1.27e-09   -1.66e-10
# LotArea:first:TotRmsAbvGrd              -1.31e-09   1.66e-09     -0.788      0.431   -4.57e-09    1.95e-09
# LotArea:first:KitchenAbvGr              1.118e-08   1.91e-08      0.587      0.558   -2.62e-08    4.86e-08
# LotArea:first:BedroomAbvGr              4.666e-09   6.94e-09      0.672      0.502   -8.96e-09    1.83e-08
# LotArea:first:GarageCars                2.624e-09   9.08e-09      0.289      0.773   -1.52e-08    2.04e-08
# LotArea:first:GarageArea                9.309e-12      2e-11      0.464      0.642      -3e-11    4.86e-11
# LotArea:second:YearRemodAdd            -6.992e-10   3.09e-10     -2.265      0.024   -1.31e-09   -9.34e-11
# LotArea:second:TotRmsAbvGrd             2.808e-09   2.36e-09      1.189      0.235   -1.82e-09    7.44e-09
# LotArea:second:KitchenAbvGr            -2.845e-08   2.46e-08     -1.158      0.247   -7.66e-08    1.98e-08
# LotArea:second:BedroomAbvGr             1.838e-08    6.9e-09      2.664      0.008    4.84e-09    3.19e-08
# LotArea:second:GarageCars               2.122e-08   1.63e-08      1.302      0.193   -1.08e-08    5.32e-08
# LotArea:second:GarageArea              -8.241e-11   5.14e-11     -1.603      0.109   -1.83e-10    1.85e-11
# LotArea:YearRemodAdd:TotRmsAbvGrd       1.253e-07   8.04e-08      1.558      0.120   -3.26e-08    2.83e-07
# LotArea:YearRemodAdd:KitchenAbvGr      -3.452e-07   3.49e-07     -0.988      0.323   -1.03e-06     3.4e-07
# LotArea:YearRemodAdd:BedroomAbvGr       1.813e-07   1.32e-07      1.374      0.170   -7.76e-08     4.4e-07
# LotArea:YearRemodAdd:GarageCars         3.526e-07   2.33e-07      1.514      0.130   -1.05e-07     8.1e-07
# LotArea:YearRemodAdd:GarageArea        -4.294e-10   8.03e-10     -0.535      0.593   -2.01e-09    1.15e-09
# LotArea:TotRmsAbvGrd:KitchenAbvGr      -4.532e-06    5.6e-06     -0.809      0.419   -1.55e-05    6.46e-06
# LotArea:TotRmsAbvGrd:BedroomAbvGr      -2.328e-06    1.4e-06     -1.667      0.096   -5.07e-06    4.12e-07
# LotArea:TotRmsAbvGrd:GarageCars        -1.501e-07   4.46e-06     -0.034      0.973    -8.9e-06     8.6e-06
# LotArea:TotRmsAbvGrd:GarageArea         9.835e-09   1.18e-08      0.831      0.406   -1.34e-08    3.31e-08
# LotArea:KitchenAbvGr:BedroomAbvGr       1.179e-05   8.19e-06      1.440      0.150   -4.28e-06    2.79e-05
# LotArea:KitchenAbvGr:GarageCars          4.61e-05   1.92e-05      2.407      0.016    8.51e-06    8.37e-05
# LotArea:KitchenAbvGr:GarageArea        -2.231e-07    6.6e-08     -3.378      0.001   -3.53e-07   -9.35e-08
# LotArea:BedroomAbvGr:GarageCars         -1.65e-05   6.33e-06     -2.607      0.009   -2.89e-05   -4.08e-06
# LotArea:BedroomAbvGr:GarageArea         5.031e-08   1.91e-08      2.639      0.008    1.29e-08    8.77e-08
# LotArea:GarageCars:GarageArea           2.084e-09   8.53e-09      0.244      0.807   -1.47e-08    1.88e-08
# YearBuilt:first:second                   3.02e-09   3.11e-09      0.972      0.331   -3.08e-09    9.12e-09
# YearBuilt:first:YearRemodAdd           -8.838e-09   5.85e-08     -0.151      0.880   -1.24e-07    1.06e-07
# YearBuilt:first:TotRmsAbvGrd           -9.673e-07   7.96e-07     -1.216      0.224   -2.53e-06    5.94e-07
# YearBuilt:first:KitchenAbvGr            6.568e-06   3.99e-06      1.648      0.100   -1.25e-06    1.44e-05
# YearBuilt:first:BedroomAbvGr           -1.572e-06   1.64e-06     -0.956      0.339    -4.8e-06    1.65e-06
# YearBuilt:first:GarageCars              3.507e-06   2.73e-06      1.287      0.198   -1.84e-06    8.85e-06
# YearBuilt:first:GarageArea             -9.615e-09   9.28e-09     -1.036      0.301   -2.78e-08     8.6e-09
# YearBuilt:second:YearRemodAdd          -7.462e-08   5.18e-08     -1.440      0.150   -1.76e-07    2.71e-08
# YearBuilt:second:TotRmsAbvGrd           7.091e-07   6.68e-07      1.061      0.289   -6.02e-07    2.02e-06
# YearBuilt:second:KitchenAbvGr          -4.417e-06   3.71e-06     -1.190      0.234   -1.17e-05    2.87e-06
# YearBuilt:second:BedroomAbvGr          -5.341e-07   1.26e-06     -0.425      0.671      -3e-06    1.93e-06
# YearBuilt:second:GarageCars             3.009e-06   2.32e-06      1.295      0.196   -1.55e-06    7.57e-06
# YearBuilt:second:GarageArea            -1.676e-08   8.77e-09     -1.911      0.056    -3.4e-08    4.49e-10
# YearBuilt:YearRemodAdd:TotRmsAbvGrd     7.949e-06   1.26e-05      0.629      0.529   -1.68e-05    3.27e-05
# YearBuilt:YearRemodAdd:KitchenAbvGr       -0.0002   3.45e-05     -4.481      0.000      -0.000   -8.69e-05
# YearBuilt:YearRemodAdd:BedroomAbvGr     3.625e-05   1.96e-05      1.850      0.065    -2.2e-06    7.47e-05
# YearBuilt:YearRemodAdd:GarageCars       3.104e-05   3.08e-05      1.007      0.314   -2.95e-05    9.15e-05
# YearBuilt:YearRemodAdd:GarageArea       3.567e-08   1.15e-07      0.310      0.756    -1.9e-07    2.61e-07
# YearBuilt:TotRmsAbvGrd:KitchenAbvGr     2.447e-05      0.001      0.030      0.976      -0.002       0.002
# YearBuilt:TotRmsAbvGrd:BedroomAbvGr     8.204e-05      0.000      0.355      0.723      -0.000       0.001
# YearBuilt:TotRmsAbvGrd:GarageCars         -0.0004      0.001     -0.470      0.639      -0.002       0.001
# YearBuilt:TotRmsAbvGrd:GarageArea       7.024e-07   2.75e-06      0.255      0.799    -4.7e-06     6.1e-06
# YearBuilt:KitchenAbvGr:BedroomAbvGr        0.0009      0.001      0.676      0.499      -0.002       0.003
# YearBuilt:KitchenAbvGr:GarageCars          0.0006      0.003      0.189      0.850      -0.006       0.007
# YearBuilt:KitchenAbvGr:GarageArea      -8.867e-06   1.15e-05     -0.771      0.441   -3.14e-05    1.37e-05
# YearBuilt:BedroomAbvGr:GarageCars         -0.0007      0.001     -0.516      0.606      -0.003       0.002
# YearBuilt:BedroomAbvGr:GarageArea       6.926e-06   4.75e-06      1.459      0.145   -2.39e-06    1.62e-05
# YearBuilt:GarageCars:GarageArea        -1.352e-06   1.55e-06     -0.874      0.383   -4.39e-06    1.68e-06
# first:second:YearRemodAdd               9.433e-09   5.21e-09      1.811      0.070   -7.87e-10    1.97e-08
# first:second:TotRmsAbvGrd               3.695e-08   4.54e-08      0.813      0.416   -5.22e-08    1.26e-07
# first:second:KitchenAbvGr              -3.892e-07   2.88e-07     -1.353      0.176   -9.54e-07    1.75e-07
# first:second:BedroomAbvGr              -1.744e-08   9.52e-08     -0.183      0.855   -2.04e-07    1.69e-07
# first:second:GarageCars                -1.299e-07   2.09e-07     -0.621      0.535    -5.4e-07    2.81e-07
# first:second:GarageArea                 8.387e-10   6.84e-10      1.226      0.220   -5.04e-10    2.18e-09
# first:YearRemodAdd:TotRmsAbvGrd        -2.684e-07   1.08e-06     -0.249      0.803   -2.38e-06    1.85e-06
# first:YearRemodAdd:KitchenAbvGr         1.674e-05   6.64e-06      2.521      0.012    3.71e-06    2.98e-05
# first:YearRemodAdd:BedroomAbvGr        -5.458e-07   2.25e-06     -0.243      0.808   -4.96e-06    3.87e-06
# first:YearRemodAdd:GarageCars          -1.139e-05   4.87e-06     -2.340      0.019   -2.09e-05   -1.84e-06
# first:YearRemodAdd:GarageArea           2.741e-08   1.59e-08      1.728      0.084   -3.72e-09    5.86e-08
# first:TotRmsAbvGrd:KitchenAbvGr        -5.187e-05   4.07e-05     -1.273      0.203      -0.000    2.81e-05
# first:TotRmsAbvGrd:BedroomAbvGr          2.71e-05   1.34e-05      2.018      0.044    7.51e-07    5.35e-05
# first:TotRmsAbvGrd:GarageCars             1.2e-05   3.51e-05      0.342      0.732   -5.68e-05    8.09e-05
# first:TotRmsAbvGrd:GarageArea          -1.357e-08   1.11e-07     -0.122      0.903   -2.32e-07    2.05e-07
# first:KitchenAbvGr:BedroomAbvGr           -0.0001      0.000     -1.099      0.272      -0.000       0.000
# first:KitchenAbvGr:GarageCars             -0.0002      0.000     -0.616      0.538      -0.001       0.000
# first:KitchenAbvGr:GarageArea           7.412e-07   1.18e-06      0.631      0.528   -1.57e-06    3.05e-06
# first:BedroomAbvGr:GarageCars              0.0001      0.000      0.997      0.319      -0.000       0.000
# first:BedroomAbvGr:GarageArea           -5.85e-07   4.02e-07     -1.454      0.146   -1.37e-06    2.05e-07
# first:GarageCars:GarageArea            -1.105e-08   1.36e-07     -0.081      0.935   -2.79e-07    2.57e-07
# second:YearRemodAdd:TotRmsAbvGrd        2.003e-08   1.12e-06      0.018      0.986   -2.18e-06    2.22e-06
# second:YearRemodAdd:KitchenAbvGr        1.511e-05   5.78e-06      2.615      0.009    3.77e-06    2.64e-05
# second:YearRemodAdd:BedroomAbvGr       -4.045e-06   2.06e-06     -1.960      0.050    -8.1e-06     4.4e-09
# second:YearRemodAdd:GarageCars         -7.646e-06   4.33e-06     -1.764      0.078   -1.62e-05     8.6e-07
# second:YearRemodAdd:GarageArea          2.574e-08   1.55e-08      1.662      0.097   -4.66e-09    5.61e-08
# second:TotRmsAbvGrd:KitchenAbvGr        5.144e-05   5.85e-05      0.880      0.379   -6.33e-05       0.000
# second:TotRmsAbvGrd:BedroomAbvGr       -2.071e-05   1.15e-05     -1.803      0.072   -4.32e-05    1.83e-06
# second:TotRmsAbvGrd:GarageCars         -7.802e-06   4.58e-05     -0.170      0.865   -9.76e-05     8.2e-05
# second:TotRmsAbvGrd:GarageArea         -5.858e-08   1.46e-07     -0.400      0.689   -3.46e-07    2.28e-07
# second:KitchenAbvGr:BedroomAbvGr        1.396e-05      0.000      0.127      0.899      -0.000       0.000
# second:KitchenAbvGr:GarageCars            -0.0002      0.000     -0.610      0.542      -0.001       0.000
# second:KitchenAbvGr:GarageArea          2.788e-07   1.09e-06      0.255      0.799   -1.87e-06    2.43e-06
# second:BedroomAbvGr:GarageCars          6.916e-05   9.35e-05      0.740      0.460      -0.000       0.000
# second:BedroomAbvGr:GarageArea         -2.574e-07    3.3e-07     -0.780      0.435   -9.05e-07     3.9e-07
# second:GarageCars:GarageArea            2.278e-07   1.34e-07      1.698      0.090   -3.55e-08    4.91e-07
# YearRemodAdd:TotRmsAbvGrd:KitchenAbvGr    -0.0010      0.001     -0.743      0.458      -0.004       0.002
# YearRemodAdd:TotRmsAbvGrd:BedroomAbvGr    -0.0003      0.000     -0.668      0.504      -0.001       0.001
# YearRemodAdd:TotRmsAbvGrd:GarageCars       0.0008      0.001      0.625      0.532      -0.002       0.004
# YearRemodAdd:TotRmsAbvGrd:GarageArea   -2.259e-06   4.54e-06     -0.497      0.619   -1.12e-05    6.66e-06
# YearRemodAdd:KitchenAbvGr:BedroomAbvGr -9.384e-05      0.002     -0.052      0.958      -0.004       0.003
# YearRemodAdd:KitchenAbvGr:GarageCars      -0.0061      0.005     -1.339      0.181      -0.015       0.003
# YearRemodAdd:KitchenAbvGr:GarageArea    1.367e-05    1.6e-05      0.853      0.394   -1.78e-05    4.51e-05
# YearRemodAdd:BedroomAbvGr:GarageCars       0.0035      0.002      1.883      0.060      -0.000       0.007
# YearRemodAdd:BedroomAbvGr:GarageArea   -1.419e-05   6.74e-06     -2.104      0.036   -2.74e-05   -9.53e-07
# YearRemodAdd:GarageCars:GarageArea      4.448e-07   2.46e-06      0.181      0.856   -4.38e-06    5.27e-06
# TotRmsAbvGrd:KitchenAbvGr:BedroomAbvGr     0.0077      0.015      0.505      0.614      -0.022       0.037
# TotRmsAbvGrd:KitchenAbvGr:GarageCars       0.0133      0.055      0.243      0.808      -0.094       0.121
# TotRmsAbvGrd:KitchenAbvGr:GarageArea    7.474e-05      0.000      0.294      0.769      -0.000       0.001
# TotRmsAbvGrd:BedroomAbvGr:GarageCars      -0.0094      0.023     -0.400      0.689      -0.055       0.037
# TotRmsAbvGrd:BedroomAbvGr:GarageArea    3.676e-05   8.78e-05      0.419      0.675      -0.000       0.000
# TotRmsAbvGrd:GarageCars:GarageArea     -6.026e-05   4.25e-05     -1.417      0.157      -0.000    2.32e-05
# KitchenAbvGr:BedroomAbvGr:GarageCars      -0.0131      0.084     -0.156      0.876      -0.178       0.152
# KitchenAbvGr:BedroomAbvGr:GarageArea    2.615e-05      0.000      0.080      0.936      -0.001       0.001
# KitchenAbvGr:GarageCars:GarageArea         0.0001      0.000      0.826      0.409      -0.000       0.000
# BedroomAbvGr:GarageCars:GarageArea      4.154e-05   5.87e-05      0.707      0.480   -7.37e-05       0.000
# ==============================================================================
# Omnibus:                      240.123   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1154.081
# Skew:                          -0.934   Prob(JB):                    2.48e-251
# Kurtosis:                       7.669   Cond. No.                     9.37e+11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.37e+11. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### 4. 벌점(릿지, 랏소), 앙상블(랜덤포레스트)을 포함하여 모형에 적합한 기계학습 모델 3가지를 제시하라
# (평가지표는 MSE, MAPE, R2 모두 확인할 것)

# %%
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

def MAPE(y_test, y_pred):
    return np.mean(np.abs((y_test - y_pred)/y_test))*100

# %%
ls=Lasso()
rd=Ridge()
rf=RandomForestRegressor()

def modelpipe(model):
    model.fit(X_train, y_train)
    model_pred=model.predict(X_test)
    mse=mean_squared_error(y_test, model_pred)
    r2score=r2_score(y_test, model_pred)
    mape=MAPE(y_test, model_pred)
    
    metrics=[mse, r2score, mape]
    return metrics

ls_result=modelpipe(ls)
rd_result=modelpipe(rd)
rf_result=modelpipe(rf)

result=pd.DataFrame([ls_result, rd_result, rf_result], columns=['mse', 'r2', 'mape'], index=['lasso', 'ridge', 'randomForest'])
result
# Out:
#                    mse        r2      mape
# lasso         0.039706  0.698146  1.130480
# ridge         0.035778  0.728009  1.067252
# randomForest  0.031156  0.763144  1.002800
