# %%
import pandas as pd
import numpy as np
data=pd.read_csv("problem3_covid2.csv")
# Out:
# C:\Users\taeeu\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\taeeu\anaconda3\lib\site-packages\numpy\.libs\libopenblas.el2c6ple4zyw3eceviv3oxxgrn2nrfm2.gfortran-win_amd64.dll
# C:\Users\taeeu\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
data.head()
# Out:
#   location        date  new_cases
# 0  Austria  2021-01-01     2096.0
# 1  Austria  2021-01-02     1391.0
# 2  Austria  2021-01-03     1466.0
# 3  Austria  2021-01-04     1642.0
# 4  Austria  2021-01-05     2311.0

# %% [markdown]
# 3-(1) 데이터는 일자별 각 나라의 일일 확진자수를 나타낸다. 각 나라의 일자별 누적확진자 수를 나타내는 데이터 프레임을 생성하라

# %%
group=data.groupby(['location','date']).sum().groupby(level=0).cumsum()

# %%
group
#누적
# Out:
#                      new_cases
# location date
# Austria  2021-01-01     2096.0
#          2021-01-02     3487.0
#          2021-01-03     4953.0
#          2021-01-04     6595.0
#          2021-01-05     8906.0
# ...                        ...
# Vanuatu  2021-10-28        5.0
#          2021-10-29        5.0
#          2021-10-30        5.0
#          2021-10-31        5.0
#          2021-11-01        5.0
#
# [11895 rows x 1 columns]

# %%
group.columns=['cumulative sum']
group=group.reset_index()
group
# Out:
#       location        date  cumulative sum
# 0      Austria  2021-01-01          2096.0
# 1      Austria  2021-01-02          3487.0
# 2      Austria  2021-01-03          4953.0
# 3      Austria  2021-01-04          6595.0
# 4      Austria  2021-01-05          8906.0
# ...        ...         ...             ...
# 11890  Vanuatu  2021-10-28             5.0
# 11891  Vanuatu  2021-10-29             5.0
# 11892  Vanuatu  2021-10-30             5.0
# 11893  Vanuatu  2021-10-31             5.0
# 11894  Vanuatu  2021-11-01             5.0
#
# [11895 rows x 3 columns]

# %%
import statsmodels.api as sm
name=[]
for lo in target['location'].unique():
    v=sm.tsa.stattools.acf(target[target['location']=='lo']['cumulative sum'], n_logs=50, fft=False)
    name.append([lo]+list(v[1:]))
v=pd.DataFrame(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp/ipykernel_34616/2458669976.py in <module>
#       1 import statsmodels.api as sm
#       2 name=[]
# ----> 3 for lo in target['location'].unique():
#       4     v=sm.tsa.stattools.acf(target[target['location']=='lo']['cumulative sum'], n_logs=50, fft=False)
#       5     name.append([lo]+list(v[1:]))
#
# NameError: name 'target' is not defined
