# %%
import pandas as pd
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
# Out:
# C:\Users\taeeu\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\taeeu\anaconda3\lib\site-packages\numpy\.libs\libopenblas.el2c6ple4zyw3eceviv3oxxgrn2nrfm2.gfortran-win_amd64.dll
# C:\Users\taeeu\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
iris=load_iris()
iris=pd.DataFrame(iris.data, columns=iris.feature_names)
iris['Class']=load_iris().target
iris['Class']=iris['Class'].map({0:'Setosa', 1:'Versicolour',2:'Virginica'})

# %%
#boxplot그리기
#Class와 같은 문자열 변수는 boxplot으로 표현할 수 없기 때문에 제외
plt.boxplot(iris.drop(columns='Class'))
plt.show()

# %%
#하나의 컬럼만 boxplot
plt.boxplot(iris['sepal width (cm)'], whis=1.5)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d1a2116100>,
#   <matplotlib.lines.Line2D at 0x1d1a2116490>],
#  'caps': [<matplotlib.lines.Line2D at 0x1d1a2116820>,
#   <matplotlib.lines.Line2D at 0x1d1a2116bb0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1d1a2104d30>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d1a2116f40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d1a2122310>],
#  'means': []}

# %%
iris[['sepal width (cm)', 'Class']].boxplot(by='Class')
plt.show()

# %%
#seaborn활용
import seaborn as sns
sns.boxplot(x="Class", y='sepal width (cm)', data=iris)
plt.show()
